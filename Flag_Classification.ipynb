# %% [markdown]
# <a href="https://colab.research.google.com/github/alok13/Machine-Learning/blob/master/Flag_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import tensorflow

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import os
import numpy as np
import glob
import shutil
import matplotlib.pyplot as plt

# %%
try:
  # Use the %tensorflow_version magic if in colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# Challenges: Collect more data.
# Understand how number of classification makes model difficult.

# %%
os.listdir("Flags Data")
# Out:
# ['Pitcairn_Islands.png',
#  'Cook_Islands.png',
#  'Bolivia.png',
#  'Democratic_Republic_of_the_Congo.png',
#  'Sudan.png',
#  'New_Zealand.png',
#  'Jamaica.png',
#  'UAE.png',
#  'Lebanon.png',
#  'Kenya.png',
#  'United_States_of_America.png',
#  'Macao.png',
#  'Kazakhstan.png',
#  'Chad.png',
#  'South_Korea.png',
#  'Faroe_Islands.png',
#  'Turks_and_Caicos_Islands.png',
#  'Palau.png',
#  'South_Africa.png',
#  'Thailand.png',
#  'Zambia.png',
#  'Djibouti.png',
#  'Turkey.png',
#  'Burkina_Faso.png',
#  'Malawi.png',
#  'Martinique.png',
#  'Morocco.png',
#  'Saint_Pierre.png',
#  'Malaysia.png',
#  'Malta.png',
#  'Czech_Republic.png',
#  'Switzerland.png',
#  'Micronesia.png',
#  'Maldives.png',
#  'Honduras.png',
#  'Philippines.png',
#  'Cyprus.png',
#  'Zimbabwe.png',
#  'Mauritius.png',
#  'Norway.png',
#  'Mozambique.png',
#  'Israel.png',
#  'Finland.png',
#  'Poland.png',
#  'Bahamas.png',
#  'Guyana.png',
#  'Ghana.png',
#  'Cyprus_Northern.png',
#  'Andorra.png',
# ...
